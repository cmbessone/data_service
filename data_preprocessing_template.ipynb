# %% [markdown]
# # Data Preprocessing Template

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("/Users/cristianbessone/inbound_data/SPO CONTENIDO1.csv")

# %%
print(dataset)
# Out:
#        Marca temporal Dirección de correo electrónico                 Nombre  \
# 0   8/5/2024 15:06:47                    juan@welu.la           573067371332
# 1   6/6/2024 17:55:52         fabianbueno09@gmail.com           Fabian Bueno
# 2   12/6/2024 9:47:45      vanesakunkel1971@gmail.com   Vanesa Kunkel Macias
# 3  12/6/2024 18:38:01          yacoacinelli@gmail.com          Yaco Acinelli
# 4  14/6/2024 10:56:27      vanesakunkel1971@gmail.com  Vanesa kunkel Macias
# 5  15/6/2024 18:55:57            almabike24@gmail.com              Alejandro
# 6  15/6/2024 18:59:44            almabike24@gmail.com              Alejandro
# 7  15/6/2024 19:02:55            almabike24@gmail.com              Alejandro
#
#              Whatsapp Tu país de residencia                     Género  \
# 0                 NaN                   NaN                        NaN
# 1          1134330684             Argentina  Masculino, Femenino, LGBT
# 2          2342455429             Argentina                   Femenino
# 3  +54 9 11 6904-6989             Argentina                  Masculino
# 4          2342455429             Argentina                   Femenino
# 5          1161476433             Argentina                  Masculino
# 6          1161476433             Argentina                  Masculino
# 7          1161476433             Argentina                  Masculino
#
#   ¿Aceptas Canje? ¿Trabajaste alguna vez con marcas?  \
# 0             NaN                                NaN
# 1              Sí                                 Sí
# 2              Sí                                 Sí
# 3              Sí                                 Sí
# 4              Sí                                 Sí
# 5              Sí                                 Sí
# 6              Sí                                 Sí
# 7              Sí                                 No
#
#             Nombre del Proyecto a Patrocinar Fecha de inicio del proyecto  \
# 0                                   WeluFest                     8/5/2024
# 1                     La Baulera Rock & Funk                     9/9/2024
# 2                       Vanesa kunkel Macias                          NaN
# 3       El proyecto se llama Yaco por Europa                     4/7/2024
# 4                      Vanesa Kunkel Macias                           NaN
# 5         Escuelas de Iniciacion al ciclismo                    15/9/2024
# 6                          Tour de Countries                    15/9/2024
# 7  Tour en Bicicleta por la Ciudad de Bs. As                    15/9/2024
#
#    ...                                         URL TikTok  \
# 0  ...  Instagram, Facebook, Twitter, TikTok, Youtube,...
# 1  ...          https://www.tiktok.com/@labaulerarockfunk
# 2  ...                    tiktok.com/@vanesa.kunkelmacias
# 3  ...      https://www.tiktok.com/@yacoaccinelli?lang=es
# 4  ...                                Vanesa.kunkelmacias
# 5  ...                                                NaN
# 6  ...                                                NaN
# 7  ...                                                NaN
#
#                                        URL Instagram  \
# 0                                                NaN
# 1       https://www.instagram.com/labaulerarockfunk/
# 2  https://www.instagram.com/vanesa.kunkelmaciaso...
# 3  https://www.instagram.com/yacoaccinelli/?hl=es-la
# 4                              Vanesa.kunkelmaciasok
# 5                       www.instagram.com7almabike24
# 6                       www.instagram.com/almabike24
# 7                       www.instagram.com/almabike24
#
#                                         URL Facebook  \
# 0                                                NaN
# 1        https://www.facebook.com/LaBaulerarockfunk/
# 2  https://www.facebook.com/share/oojWFDURssbcVHx...
# 3                                                NaN
# 4                                Vanesa.kunkelmacias
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                               URL YouTube  \
# 0                                     NaN
# 1                      @LaBauleraRockFunk
# 2                                     NaN
# 3  https://www.youtube.com/@YacoAccinelli
# 4                           Vanesa kunkel
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
#
#                             URL Twitch                        URL Kick  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3  https://www.twitch.tv/yacoaccinelli  https://kick.com/yacoaccinelli
# 4                                  NaN                             NaN
# 5                                  NaN                             NaN
# 6                                  NaN                             NaN
# 7                                  NaN                             NaN
#
#   URL  X (Twitter) URL  Linkedin URL otra  Red social que tengas   \
# 0              NaN           NaN                              NaN
# 1              NaN           NaN                              NaN
# 2              NaN           NaN                              NaN
# 3              NaN           NaN                              NaN
# 4    Vanesa kunkel           NaN                              NaN
# 5              NaN           NaN                              NaN
# 6              NaN           NaN                              NaN
# 7              NaN           NaN                              NaN
#
#   Proyecto de responsabilidad sustentable?
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                       Si
# 6                                       Si
# 7                                       Si
#
# [8 rows x 37 columns]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from pymongo import MongoClient
from django.conf import settings

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from django.conf import settings

database='mydatabase'
# Conexión a MongoDB
client = MongoClient('localhost', 27017)
db = client[database]
collection_name = 'SPOContenido1'  # Reemplaza con el nombre de tu colección
collection = db[collection_name]

# Convertir los datos de MongoDB a un DataFrame de Pandas
cursor = collection.find()
df = pd.DataFrame(list(cursor))

features = ['¿Aceptas Canje?', 'Rubros de marcas', 'Beneficios a la Marca', 'Valores del Proyecto']
# Filtrar las columnas relevantes
df_filtered = df[features]

le = LabelEncoder()
df_filtered['¿Aceptas Canje?'] = le.fit_transform(df_filtered['¿Aceptas Canje?'].astype(str))

print(df_filtered)

print('Carga Exitosa')
# Cerrar la conexión a MongoDB
client.close()
# Out:
#    ¿Aceptas Canje?                                   Rubros de marcas  \
# 0                0  Gastronomia, Hardware, Indumentaria, Sector Fi...
# 1                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
# 2                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
# 3                1                        Técnologia, Entretenimiento
# 4                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
# 5                1                Entretenimiento, Deporte Recreativo
# 6                1  Bebida sin Alcochol, Gastronomia, Hardware, In...
# 7                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
#
#                                Beneficios a la Marca  \
# 0                                 Conversión (venta)
# 1                                            Tráfico
# 2  Alcance, Tráfico, Seguidores, Leads, Conversió...
# 3  Alcance, Tráfico, Seguidores, Leads, Conversió...
# 4   Alcance, Tráfico, Seguidores, Conversión (venta)
# 5
# 6   Alcance, Tráfico, Seguidores, Conversión (venta)
# 7   Alcance, Tráfico, Seguidores, Conversión (venta)
#
#                                 Valores del Proyecto
# 0  Empatía, Pasión, Diversión, Responsabilidad so...
# 1               Pasión, Diversión, Trabajo en equipo
# 2                                  Trabajo en equipo
# 3  Empatía, Pasión, Diversión, Humor, Logros pers...
# 4  Competitividad, Empatía, Pasión, Diversión, Tr...
# 5                         Empatía, Pasión, Diversión
# 6         Empatía, Diversión, Responsabilidad social
# 7                                 Empatía, Diversión
# Carga Exitosa
# /var/folders/m9/83wb1s2d2vg9d4jgb1svxnz00000gn/T/ipykernel_34074/231790454.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['¿Aceptas Canje?'] = le.fit_transform(df_filtered['¿Aceptas Canje?'].astype(str))

# %%
display(df)
# Out:
#                         _id      Marca temporal  \
# 0  666fbff4ef61aa1e00665044   8/5/2024 15:06:47
# 1  666fbff4ef61aa1e00665045   6/6/2024 17:55:52
# 2  666fbff4ef61aa1e00665046   12/6/2024 9:47:45
# 3  666fbff4ef61aa1e00665047  12/6/2024 18:38:01
# 4  666fbff4ef61aa1e00665048  14/6/2024 10:56:27
# 5  666fbff4ef61aa1e00665049  15/6/2024 18:55:57
# 6  666fbff4ef61aa1e0066504a  15/6/2024 18:59:44
# 7  666fbff4ef61aa1e0066504b  15/6/2024 19:02:55
#
#   Dirección de correo electrónico                 Nombre            Whatsapp  \
# 0                    juan@welu.la           573067371332
# 1         fabianbueno09@gmail.com           Fabian Bueno          1134330684
# 2      vanesakunkel1971@gmail.com   Vanesa Kunkel Macias          2342455429
# 3          yacoacinelli@gmail.com          Yaco Acinelli  +54 9 11 6904-6989
# 4      vanesakunkel1971@gmail.com  Vanesa kunkel Macias           2342455429
# 5            almabike24@gmail.com              Alejandro          1161476433
# 6            almabike24@gmail.com              Alejandro          1161476433
# 7            almabike24@gmail.com              Alejandro          1161476433
#
#   Tu país de residencia                     Género ¿Aceptas Canje?  \
# 0
# 1             Argentina  Masculino, Femenino, LGBT              Sí
# 2             Argentina                   Femenino              Sí
# 3             Argentina                  Masculino              Sí
# 4             Argentina                   Femenino              Sí
# 5             Argentina                  Masculino              Sí
# 6             Argentina                  Masculino              Sí
# 7             Argentina                  Masculino              Sí
#
#   ¿Trabajaste alguna vez con marcas?  \
# 0
# 1                                 Sí
# 2                                 Sí
# 3                                 Sí
# 4                                 Sí
# 5                                 Sí
# 6                                 Sí
# 7                                 No
#
#             Nombre del Proyecto a Patrocinar  ...  \
# 0                                   WeluFest  ...
# 1                     La Baulera Rock & Funk  ...
# 2                       Vanesa kunkel Macias  ...
# 3       El proyecto se llama Yaco por Europa  ...
# 4                      Vanesa Kunkel Macias   ...
# 5         Escuelas de Iniciacion al ciclismo  ...
# 6                          Tour de Countries  ...
# 7  Tour en Bicicleta por la Ciudad de Bs. As  ...
#
#                                           URL TikTok  \
# 0  Instagram, Facebook, Twitter, TikTok, Youtube,...
# 1          https://www.tiktok.com/@labaulerarockfunk
# 2                    tiktok.com/@vanesa.kunkelmacias
# 3      https://www.tiktok.com/@yacoaccinelli?lang=es
# 4                                Vanesa.kunkelmacias
# 5
# 6
# 7
#
#                                        URL Instagram  \
# 0
# 1       https://www.instagram.com/labaulerarockfunk/
# 2  https://www.instagram.com/vanesa.kunkelmaciaso...
# 3  https://www.instagram.com/yacoaccinelli/?hl=es-la
# 4                              Vanesa.kunkelmaciasok
# 5                       www.instagram.com7almabike24
# 6                       www.instagram.com/almabike24
# 7                       www.instagram.com/almabike24
#
#                                         URL Facebook  \
# 0
# 1        https://www.facebook.com/LaBaulerarockfunk/
# 2  https://www.facebook.com/share/oojWFDURssbcVHx...
# 3
# 4                                Vanesa.kunkelmacias
# 5
# 6
# 7
#
#                               URL YouTube  \
# 0
# 1                      @LaBauleraRockFunk
# 2
# 3  https://www.youtube.com/@YacoAccinelli
# 4                           Vanesa kunkel
# 5
# 6
# 7
#
#                             URL Twitch                        URL Kick  \
# 0
# 1
# 2
# 3  https://www.twitch.tv/yacoaccinelli  https://kick.com/yacoaccinelli
# 4
# 5
# 6
# 7
#
#   URL  X (Twitter) URL  Linkedin URL otra  Red social que tengas   \
# 0
# 1
# 2
# 3
# 4    Vanesa kunkel
# 5
# 6
# 7
#
#   Proyecto de responsabilidad sustentable?
# 0
# 1
# 2
# 3
# 4
# 5                                       Si
# 6                                       Si
# 7                                       Si
#
# [8 rows x 38 columns]

# %%
display(dataset)
# Out:
#        Marca temporal Dirección de correo electrónico                 Nombre  \
# 0   8/5/2024 15:06:47                    juan@welu.la           573067371332
# 1   6/6/2024 17:55:52         fabianbueno09@gmail.com           Fabian Bueno
# 2   12/6/2024 9:47:45      vanesakunkel1971@gmail.com   Vanesa Kunkel Macias
# 3  12/6/2024 18:38:01          yacoacinelli@gmail.com          Yaco Acinelli
# 4  14/6/2024 10:56:27      vanesakunkel1971@gmail.com  Vanesa kunkel Macias
# 5  15/6/2024 18:55:57            almabike24@gmail.com              Alejandro
# 6  15/6/2024 18:59:44            almabike24@gmail.com              Alejandro
# 7  15/6/2024 19:02:55            almabike24@gmail.com              Alejandro
#
#              Whatsapp Tu país de residencia                     Género  \
# 0                 NaN                   NaN                        NaN
# 1          1134330684             Argentina  Masculino, Femenino, LGBT
# 2          2342455429             Argentina                   Femenino
# 3  +54 9 11 6904-6989             Argentina                  Masculino
# 4          2342455429             Argentina                   Femenino
# 5          1161476433             Argentina                  Masculino
# 6          1161476433             Argentina                  Masculino
# 7          1161476433             Argentina                  Masculino
#
#   ¿Aceptas Canje? ¿Trabajaste alguna vez con marcas?  \
# 0             NaN                                NaN
# 1              Sí                                 Sí
# 2              Sí                                 Sí
# 3              Sí                                 Sí
# 4              Sí                                 Sí
# 5              Sí                                 Sí
# 6              Sí                                 Sí
# 7              Sí                                 No
#
#             Nombre del Proyecto a Patrocinar Fecha de inicio del proyecto  \
# 0                                   WeluFest                     8/5/2024
# 1                     La Baulera Rock & Funk                     9/9/2024
# 2                       Vanesa kunkel Macias                          NaN
# 3       El proyecto se llama Yaco por Europa                     4/7/2024
# 4                      Vanesa Kunkel Macias                           NaN
# 5         Escuelas de Iniciacion al ciclismo                    15/9/2024
# 6                          Tour de Countries                    15/9/2024
# 7  Tour en Bicicleta por la Ciudad de Bs. As                    15/9/2024
#
#    ...                                         URL TikTok  \
# 0  ...  Instagram, Facebook, Twitter, TikTok, Youtube,...
# 1  ...          https://www.tiktok.com/@labaulerarockfunk
# 2  ...                    tiktok.com/@vanesa.kunkelmacias
# 3  ...      https://www.tiktok.com/@yacoaccinelli?lang=es
# 4  ...                                Vanesa.kunkelmacias
# 5  ...                                                NaN
# 6  ...                                                NaN
# 7  ...                                                NaN
#
#                                        URL Instagram  \
# 0                                                NaN
# 1       https://www.instagram.com/labaulerarockfunk/
# 2  https://www.instagram.com/vanesa.kunkelmaciaso...
# 3  https://www.instagram.com/yacoaccinelli/?hl=es-la
# 4                              Vanesa.kunkelmaciasok
# 5                       www.instagram.com7almabike24
# 6                       www.instagram.com/almabike24
# 7                       www.instagram.com/almabike24
#
#                                         URL Facebook  \
# 0                                                NaN
# 1        https://www.facebook.com/LaBaulerarockfunk/
# 2  https://www.facebook.com/share/oojWFDURssbcVHx...
# 3                                                NaN
# 4                                Vanesa.kunkelmacias
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                               URL YouTube  \
# 0                                     NaN
# 1                      @LaBauleraRockFunk
# 2                                     NaN
# 3  https://www.youtube.com/@YacoAccinelli
# 4                           Vanesa kunkel
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
#
#                             URL Twitch                        URL Kick  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3  https://www.twitch.tv/yacoaccinelli  https://kick.com/yacoaccinelli
# 4                                  NaN                             NaN
# 5                                  NaN                             NaN
# 6                                  NaN                             NaN
# 7                                  NaN                             NaN
#
#   URL  X (Twitter) URL  Linkedin URL otra  Red social que tengas   \
# 0              NaN           NaN                              NaN
# 1              NaN           NaN                              NaN
# 2              NaN           NaN                              NaN
# 3              NaN           NaN                              NaN
# 4    Vanesa kunkel           NaN                              NaN
# 5              NaN           NaN                              NaN
# 6              NaN           NaN                              NaN
# 7              NaN           NaN                              NaN
#
#   Proyecto de responsabilidad sustentable?
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                       Si
# 6                                       Si
# 7                                       Si
#
# [8 rows x 37 columns]

# %%
display(df_filtered)
# Out:
#    ¿Aceptas Canje?                                   Rubros de marcas  \
# 0                0  Gastronomia, Hardware, Indumentaria, Sector Fi...
# 1                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
# 2                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
# 3                1                        Técnologia, Entretenimiento
# 4                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
# 5                1                Entretenimiento, Deporte Recreativo
# 6                1  Bebida sin Alcochol, Gastronomia, Hardware, In...
# 7                1  Automotor, Bebida con Alcochol, Bebida sin Alc...
#
#                                Beneficios a la Marca  \
# 0                                 Conversión (venta)
# 1                                            Tráfico
# 2  Alcance, Tráfico, Seguidores, Leads, Conversió...
# 3  Alcance, Tráfico, Seguidores, Leads, Conversió...
# 4   Alcance, Tráfico, Seguidores, Conversión (venta)
# 5
# 6   Alcance, Tráfico, Seguidores, Conversión (venta)
# 7   Alcance, Tráfico, Seguidores, Conversión (venta)
#
#                                 Valores del Proyecto
# 0  Empatía, Pasión, Diversión, Responsabilidad so...
# 1               Pasión, Diversión, Trabajo en equipo
# 2                                  Trabajo en equipo
# 3  Empatía, Pasión, Diversión, Humor, Logros pers...
# 4  Competitividad, Empatía, Pasión, Diversión, Tr...
# 5                         Empatía, Pasión, Diversión
# 6         Empatía, Diversión, Responsabilidad social
# 7                                 Empatía, Diversión
